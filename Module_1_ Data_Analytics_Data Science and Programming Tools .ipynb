# %% [markdown]
#                              LAB ASSIGNMENTS
#
#                 Module 1: Data Science and Programming Tools
#
#                               Data Analytics

# %% [markdown]
# ### Q1. Find all statistics using describe function on following on train_XnW6LSF.csv dataset

# %%
#Importing required libraries in one cell followed as a best practise in every Jupyter notebook

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Importing dataframe 

df = pd.read_csv(r"D:\1_AJINKYA_PAWAR\3_SOFTWARE JOB\1_CDAC\3_AI_Course\Lab_Assignment_Module_1\train_XnW6LSF.csv")
df
#Dataframe imported and displayed as below
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# #### Q1: A. Records of every item:: describe various statistics about every item type record

# %%
#First of all we will find out the names of every item type record using .column property. 
# The columns property returns the label of each column in the DataFrame.

df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
#Catrgorical columns are filterd and only numerical columns are displayed. 

print(df[['Item_Identifier','Item_Weight','Item_Fat_Content','Item_Visibility',
       'Item_Type', 'Item_MRP' ]].describe())
# Out:
#        Item_Weight  Item_Visibility     Item_MRP
# count  7060.000000      8523.000000  8523.000000
# mean     12.857645         0.066132   140.992782
# std       4.643456         0.051598    62.275067
# min       4.555000         0.000000    31.290000
# 25%       8.773750         0.026989    93.826500
# 50%      12.600000         0.053931   143.012800
# 75%      16.850000         0.094585   185.643700
# max      21.350000         0.328391   266.888400

# %% [markdown]
# #### Q2: B. Records of every Outlet_Location_Type:: describe various statistics about every Outlet_Location_Type record

# %%
#Catrgorical columns are filterd and only numerical columns are displayed. 



print(df[['Outlet_Identifier', 'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type',  'Item_Outlet_Sales']].describe())
# Out:
#        Outlet_Establishment_Year  Item_Outlet_Sales
# count                8523.000000        8523.000000
# mean                 1997.831867        2181.288914
# std                     8.371760        1706.499616
# min                  1985.000000          33.290000
# 25%                  1987.000000         834.247400
# 50%                  1999.000000        1794.331000
# 75%                  2004.000000        3101.296400
# max                  2009.000000       13086.964800

# %%
#COMMON ANSWER for Q1 A and B 

#For Q1 A and B, same answers can be obtined simply by applying describe for whole dataframe.
#It keeps aside categorical columns and gives us the output. 

# In Pandas decribe() method is used to find various statistics about every(Numerical) record. 

df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
#                                             ***

# %% [markdown]
# #### Q2. Analyze location type wise Dairy product sales

# %%
# For this question we will analyse location typewise sales using describe method. 
# Here groupby is used to analyse location typewise sales 

sales_analysis = df.groupby('Outlet_Location_Type')['Item_Outlet_Sales'].describe()

sales_analysis
# Out:
#                        count         mean          std      min         25%  \
# Outlet_Location_Type
# Tier 1                2388.0  1876.909159  1561.649293  33.9558   593.72715
# Tier 2                2785.0  2323.990559  1520.543543  99.8700  1171.80800
# Tier 3                3350.0  2279.627651  1912.451333  33.2900   731.38130
#
#                             50%        75%         max
# Outlet_Location_Type
# Tier 1                1487.3972  2803.0180   9779.9362
# Tier 2                2004.0580  3110.6176   9664.7528
# Tier 3                1812.3076  3307.6944  13086.9648

# %% [markdown]
#                                             ***

# %% [markdown]
# #### Q3. Which outlets are oldest? Arrange outlets as per their age of establishment

# %%
# To find oldest outlet we will first findout oldest year of establishment 
# Then we will filter the outlets based on the oldest year and disolay their names. 
# After that we will arrange the outletes as per their establishment in the dataframe. 

df['Outlet_Establishment_Year'].min()
# Out:
# 1985

# %%
#we will filter the outlets based on the oldest year and disolay their name

oldest_outlets = df.loc[df['Outlet_Establishment_Year'] == 1985]
                     
oldest_outlets #It displayed total 1463 outelets with

#However when unique method is applied on 'Outlet_Identifier' and 'Outlet_Type' it showed only two outlets. 
#they are displayed in the next cells.
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 18             DRI11          NaN          Low Fat         0.034238
# 21             FDW12          NaN          Regular         0.035400
# 23             FDC37          NaN          Low Fat         0.057557
# 29             FDC14          NaN          Regular         0.072222
# ...              ...          ...              ...              ...
# 8485           DRK37          NaN          Low Fat         0.043792
# 8487           DRG13          NaN          Low Fat         0.037006
# 8488           NCN14          NaN          Low Fat         0.091473
# 8490           FDU44          NaN          Regular         0.102296
# 8504           NCN18          NaN          Low Fat         0.124111
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7               Snack Foods  107.7622            OUT027
# ...

# %%
#As per outlet identifier 'OUT027', 'OUT019' are the oldest outlets

oldest_outlets['Outlet_Identifier'].unique()
# Out:
# array(['OUT027', 'OUT019'], dtype=object)

# %%
#As per outlet type 'Supermarket Type3', 'Grocery Store' are the oldest outlets

oldest_outlets['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type3', 'Grocery Store'], dtype=object)

# %%
# Arranging the outlets as per their age of establishment. We will .sort_values method. 

df_sorted = df.sort_values('Outlet_Establishment_Year')

df_sorted
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4338           FDH21          NaN          Low Fat         0.031074
# 3689           FDD53          NaN          Low Fat         0.044008
# 1139           FDH26          NaN          Regular         0.034532
# 1138           FDM21          NaN          Low Fat         0.064052
# 3691           FDY36          NaN          Low Fat         0.016477
# ...              ...          ...              ...              ...
# 3600           FDX31        20.35          Regular         0.014886
# 5053           NCO53        16.20          Low Fat         0.175898
# 7710           NCR18        15.85          Low Fat         0.020571
# 5750           FDV26        20.25          Regular         0.076471
# 7378           FDJ26        15.30          Regular         0.085110
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4338                Seafood  157.5604            OUT027
# ...

# %% [markdown]
#                                             ***

# %% [markdown]
# #### Q4. Which high size outlets are having minimum low fat / LF products?
# #### Is there any small size outlet close to such these values of stocks for low fat / LF?

# %%
# high size outlets are having minimum low fat / LF product

highsize_lowfat_outlets = df.loc[(df['Outlet_Size'] == 'High') & (df['Item_Fat_Content'] == 'Low Fat')]

highsize_lowfat_outlets #It shows comptehensive list 

# However when .unique method is applied on Outlet_Type it shows "Supermarket Type 1" as the answer.
# It is displayed in the next cell
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4              NCD19        8.930          Low Fat         0.000000
# 14             FDF32       16.350          Low Fat         0.068024
# 41             FDK43        9.800          Low Fat         0.026818
# 51             FDM40       10.195          Low Fat         0.159804
# 109            DRK49       14.150          Low Fat         0.035914
# ...              ...          ...              ...              ...
# 8438           FDE26        9.300          Low Fat         0.088932
# 8466           FDJ32       10.695          Low Fat         0.057744
# 8484           DRJ49        6.865          Low Fat         0.000000
# 8512           FDR26       20.700          Low Fat         0.042801
# 8518           FDF22        6.865          Low Fat         0.056783
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 4                 Household   53.8614            OUT013
# ...

# %%
#Name of high size low fat outlet.

highsize_lowfat_outlets['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1'], dtype=object)

# %% [markdown]
# #### Q4: Part 2: Is there any small size outlet close to such these values of stocks for low fat / LF?

# %%
#small size outlet close to such these values of stocks for low fat / LF


smallsize_lowfat_outlets = df.loc[(df['Outlet_Size'] == 'Small') & (df['Item_Fat_Content'] == 'Low Fat')]

smallsize_lowfat_outlets


# After using unique method we found- 'Supermarket Type1', 'Grocery Store' are the small size outlet 
# close to such these values of stocks for low fat / LF. Displayed in the next cell.
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 19             FDU02        13.35          Low Fat         0.102492
# 22             NCB30        14.60          Low Fat         0.025698
# 23             FDC37          NaN          Low Fat         0.057557
# 34             DRH01        17.50          Low Fat         0.097904
# 40             FDU02        13.35          Low Fat         0.102512
# ...              ...          ...              ...              ...
# 8497           FDT08        13.65          Low Fat         0.049209
# 8499           NCK53        11.60          Low Fat         0.037574
# 8503           FDQ44        20.50          Low Fat         0.036133
# 8520           NCJ29        10.60          Low Fat         0.035186
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 19                    Dairy  230.5352            OUT035
# ...

# %%
# small size outlet close to such these values of stocks for low fat / LF. 

smallsize_lowfat_outlets['Outlet_Type'].unique()
# Out:
# array(['Supermarket Type1', 'Grocery Store'], dtype=object)

# %% [markdown]
#                                             ***

# %% [markdown]
# #### Q5: 5. Find the items which have MRP higher than 200 and count how many of them are low fat / LF, reg fat / reg

# %%
# items which have MRP higher than 200

MRP_outlets = df.loc[ df['Item_MRP'] >= 200] 

MRP_outlets
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 19             FDU02       13.350          Low Fat         0.102492
# 20             FDN22       18.850          Regular         0.138190
# 32             FDP33       18.700          Low Fat         0.000000
# 40             FDU02       13.350          Low Fat         0.102512
# ...              ...          ...              ...              ...
# 8506           DRF37       17.250          Low Fat         0.084676
# 8509           FDG45        8.100          Low Fat         0.214306
# 8510           FDN58       13.800          Regular         0.056862
# 8511           FDF05       17.500          Low Fat         0.026980
# 8518           FDF22        6.865          Low Fat         0.056783
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
# Items whose MRP is greater than 200 and have low fat content 
lowfat_outlets = MRP_outlets.loc[MRP_outlets['Item_Fat_Content'] == 'Low Fat'] 

lowfat_outlets.count()

#Answer: Total 862 items have MRP greater than 200 and low fat content
# Out:
# Item_Identifier              862
# Item_Weight                  725
# Item_Fat_Content             862
# Item_Visibility              862
# Item_Type                    862
# Item_MRP                     862
# Outlet_Identifier            862
# Outlet_Establishment_Year    862
# Outlet_Size                  616
# Outlet_Location_Type         862
# Outlet_Type                  862
# Item_Outlet_Sales            862
# dtype: int64

# %%
# Items whose MRP is greater than 200 and have reg fat content 
regfat_outlets = MRP_outlets.loc[MRP_outlets['Item_Fat_Content'] == 'Regular'] 

regfat_outlets.count()

#Answer: Total 488 items have MRP greater than 200 and low fat content
# Out:
# Item_Identifier              488
# Item_Weight                  407
# Item_Fat_Content             488
# Item_Visibility              488
# Item_Type                    488
# Item_MRP                     488
# Outlet_Identifier            488
# Outlet_Establishment_Year    488
# Outlet_Size                  359
# Outlet_Location_Type         488
# Outlet_Type                  488
# Item_Outlet_Sales            488
# dtype: int64

# %% [markdown]
# #### Q6: Find the outlets with highest sales in Tier 2. Also find similar outlets in Tier 3 locations?

# %% [markdown]
# #### Q6 Part 1

# %%
# Q6 Part 1
#First of all we will find out Outlets with highest sales in Tier 2. 

tier2_outlets= df.loc[df['Outlet_Location_Type'] == 'Tier 2'] 
tier2_outlets
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8              FDH17        16.20          Regular         0.016687
# 9              FDU28        19.20          Regular         0.094450
# 19             FDU02        13.35          Low Fat         0.102492
# 22             NCB30        14.60          Low Fat         0.025698
# 25             NCD06        13.00          Low Fat         0.099887
# ...              ...          ...              ...              ...
# 8510           FDN58        13.80          Regular         0.056862
# 8513           FDH31        12.00          Regular         0.020407
# 8514           FDA01        15.00          Regular         0.054489
# 8519           FDS36         8.38          Regular         0.046982
# 8520           NCJ29        10.60          Low Fat         0.035186
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8           Frozen Foods   96.9726            OUT045
# ...

# %%
#Now we will find out highest sales in tier 2 
tier2_outlets['Item_Outlet_Sales'].max()
# Out:
# 9664.7528

# %%
# based on the value 96664.7528 we will identify the highest selling outlets in tier 2

highestsales_tier2_outlets= tier2_outlets.loc[tier2_outlets['Item_Outlet_Sales'] == 9664.7528] 
highestsales_tier2_outlets

# OUT017 i.e. Supermarket Type1 is the highest selling outlet in tier 2.
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility Item_Type  \
# 4961           FDK03         12.6          Regular         0.074339     Dairy
#
#       Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 4961  255.5356            OUT017                       2007         NaN
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 4961               Tier 2  Supermarket Type1          9664.7528

# %% [markdown]
# #### Q6 Part 2

# %%
# Q6 Part 2
#First of all we will find out Outlets with highest sales in Tier 3. 

tier3_outlets= df.loc[df['Outlet_Location_Type'] == 'Tier 3'] 
tier3_outlets
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              DRC01        5.920          Regular         0.019278
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# ...              ...          ...              ...              ...
# 8512           FDR26       20.700          Low Fat         0.042801
# 8515           FDH24       20.700          Low Fat         0.021518
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8518           FDF22        6.865          Low Fat         0.056783
# 8521           FDN46        7.210          Regular         0.145221
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 1               Soft Drinks   48.2692            OUT018
# ...

# %%
#Now we will find out highest sales in tier 3
tier3_outlets['Item_Outlet_Sales'].max()
# Out:
# 13086.9648

# %%
# based on the value 96664.7528 we will identify the highest selling outlets in tier 3

highestsales_tier3_outlets= tier3_outlets.loc[tier3_outlets['Item_Outlet_Sales'] == 13086.9648] 
highestsales_tier3_outlets

# OUT027 i.e. Supermarket Type3 is the highest selling outlet in tier 3.
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7188           NCE42          NaN          Low Fat         0.010551
#
#       Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 7188  Household  234.9958            OUT027                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 7188      Medium               Tier 3  Supermarket Type3         13086.9648

# %% [markdown]
#                                             ***
