# %% [markdown]
#                                                 LAB ASSIGNMENTS
#                                             Module 2: Machine Learning

# %% [markdown]
#                                                     K-Means

# %% [markdown]
# Q1. Consider the dataset nutrient.csv . Carry out a cluster analysis of the data. Do the K-means clustering and also choose the appropriate number of clusters

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Loading the dataset
data = pd.read_csv(r'D:\1_AJINKYA_PAWAR\3_SOFTWARE JOB\1_CDAC\3_AI_Course\Lab_Assignment_Module_2\2_4_3_K_Means_1Hr\nutrient.csv')

data
# Out:
#               Food_Item  energy  protein  fat  calcium  iron
# 0          BEEF BRAISED     340       20   28        9   2.6
# 1             HAMBURGER     245       21   17        9   2.7
# 2            BEEF ROAST     420       15   39        7   2.0
# 3            BEEF STEAK     375       19   32        9   2.6
# 4           BEEF CANNED     180       22   10       17   3.7
# 5       CHICKEN BROILED     115       20    3        8   1.4
# 6        CHICKEN CANNED     170       25    7       12   1.5
# 7            BEEF HEART     160       26    5       14   5.9
# 8        LAMB LEG ROAST     265       20   20        9   2.6
# 9   LAMB SHOULDER ROAST     300       18   25        9   2.3
# 10           SMOKED HAM     340       20   28        9   2.5
# 11           PORK ROAST     340       19   29        9   2.5
# 12        PORK SIMMERED     355       19   30        9   2.4
# 13          BEEF TONGUE     205       18   14        7   2.5
# ...

# %%
# Selecting the relevant features for clustering

features = data[['protein', 'fat', 'calcium']]

# Standardizing the data
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Initializing a list to store the inertia (sum of squared distances)
inertia = []

# Defining a range of cluster numbers to try
cluster_range = range(1, 11)

# Performing K-means clustering for different cluster numbers
for n_clusters in cluster_range:
    kmeans = KMeans(n_clusters=n_clusters, random_state=0)
    kmeans.fit(scaled_features)
    inertia.append(kmeans.inertia_)

# Plotting the Elbow Method graph
plt.figure(figsize=(8, 6))
plt.plot(cluster_range, inertia, marker='o')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.grid(True)
plt.show()
# Out:
# C:\Users\ajink\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\ajink\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\ajink\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# Choosing the number of clusters based on the Elbow Method
# Looking for the "elbow point" in the plot
# In this example, we'll assume the "elbow" occurs at cluster_num = 3
cluster_num = 3

# Performing K-means clustering with the chosen number of clusters
kmeans = KMeans(n_clusters=cluster_num, random_state=0)
cluster_labels = kmeans.fit_predict(scaled_features)

# Adding cluster labels to the original dataset
data['Cluster'] = cluster_labels
# Out:
# C:\Users\ajink\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\ajink\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
data
# Out:
#               Food_Item  energy  protein  fat  calcium  iron  Cluster
# 0          BEEF BRAISED     340       20   28        9   2.6        2
# 1             HAMBURGER     245       21   17        9   2.7        0
# 2            BEEF ROAST     420       15   39        7   2.0        2
# 3            BEEF STEAK     375       19   32        9   2.6        2
# 4           BEEF CANNED     180       22   10       17   3.7        0
# 5       CHICKEN BROILED     115       20    3        8   1.4        0
# 6        CHICKEN CANNED     170       25    7       12   1.5        0
# 7            BEEF HEART     160       26    5       14   5.9        0
# 8        LAMB LEG ROAST     265       20   20        9   2.6        2
# 9   LAMB SHOULDER ROAST     300       18   25        9   2.3        2
# 10           SMOKED HAM     340       20   28        9   2.5        2
# 11           PORK ROAST     340       19   29        9   2.5        2
# ...

# %% [markdown]
#                                                             ***

# %% [markdown]
# Q2: Perform k means clustering milk.csv dataset , use StandardScalar() and calculate linkage: merging

# %%
# Loading the dataset
data1 = pd.read_csv(r'D:\1_AJINKYA_PAWAR\3_SOFTWARE JOB\1_CDAC\3_AI_Course\Lab_Assignment_Module_2\2_4_3_K_Means_1Hr\milk.csv')

data1
# Out:
#         Animal  water  protein   fat  lactose   ash
# 0        HORSE   90.1      2.6   1.0      6.9  0.35
# 1    ORANGUTAN   88.5      1.4   3.5      6.0  0.24
# 2       MONKEY   88.4      2.2   2.7      6.4  0.18
# 3       DONKEY   90.3      1.7   1.4      6.2  0.40
# 4        HIPPO   90.4      0.6   4.5      4.4  0.10
# 5        CAMEL   87.7      3.5   3.4      4.8  0.71
# 6        BISON   86.9      4.8   1.7      5.7  0.90
# 7      BUFFALO   82.1      5.9   7.9      4.7  0.78
# 8   GUINEA PIG   81.9      7.4   7.2      2.7  0.85
# 9          CAT   81.6     10.1   6.3      4.4  0.75
# 10         FOX   81.6      6.6   5.9      4.9  0.93
# 11       LLAMA   86.5      3.9   3.2      5.6  0.80
# 12        MULE   90.0      2.0   1.8      5.5  0.47
# 13         PIG   82.8      7.1   5.1      3.7  1.10
# 14       ZEBRA   86.2      3.0   4.8      5.3  0.70
# 15       SHEEP   82.0      5.6   6.4      4.7  0.91
# 16         DOG   76.3      9.3   9.5      3.0  1.20
# ...

# %%
# Selecting the features you want to use for clustering

features = data1[['water', 'protein', 'fat']] 

# Standardizing the data using StandardScaler
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Defining the number of clusters
num_clusters = 3  # You can adjust this based on your problem

# Performing K-means clustering
kmeans = KMeans(n_clusters=num_clusters, random_state=0)
cluster_labels = kmeans.fit_predict(scaled_features)

# Adding cluster labels to the original dataset
data1['Cluster'] = cluster_labels
# Out:
# C:\Users\ajink\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\ajink\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
data1
# Out:
#         Animal  water  protein   fat  lactose   ash  Cluster
# 0        HORSE   90.1      2.6   1.0      6.9  0.35        1
# 1    ORANGUTAN   88.5      1.4   3.5      6.0  0.24        1
# 2       MONKEY   88.4      2.2   2.7      6.4  0.18        1
# 3       DONKEY   90.3      1.7   1.4      6.2  0.40        1
# 4        HIPPO   90.4      0.6   4.5      4.4  0.10        1
# 5        CAMEL   87.7      3.5   3.4      4.8  0.71        1
# 6        BISON   86.9      4.8   1.7      5.7  0.90        1
# 7      BUFFALO   82.1      5.9   7.9      4.7  0.78        1
# 8   GUINEA PIG   81.9      7.4   7.2      2.7  0.85        1
# 9          CAT   81.6     10.1   6.3      4.4  0.75        0
# 10         FOX   81.6      6.6   5.9      4.9  0.93        1
# 11       LLAMA   86.5      3.9   3.2      5.6  0.80        1
# 12        MULE   90.0      2.0   1.8      5.5  0.47        1
# 13         PIG   82.8      7.1   5.1      3.7  1.10        1
# ...

# %%
                                                            ***
